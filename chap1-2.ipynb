# %%
#한글폰트 파일실행(방법1)

# !python han-font.py
exec(open('han-font.py').read())

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pit

# %%
df=pd.read_excel('Weight_Sample.xlsx')
df.set_index('ID')

sns.histplot(data = df, x="체중", kde=True)
pit.title("체중 분포")
pit.show()

# %%
from matplotlib import font_manager, rc

font_name=font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

sns.histplot(data=df, x='체중', hue='성별', hue_order=[1, 0], kde=True)
plt.title("성별에 따른 체중 분포")
plt.legend(['여성', '남성'])
plt.show()

# %%
sns.pairplot(data=df)
df.corr()
# Out:
#           ID        체중         키        성별        나이
# ID  1.000000  0.025936  0.062238  0.057039 -0.055526
# 체중  0.025936  1.000000  0.793278  0.822990  0.206245
# 키   0.062238  0.793278  1.000000  0.764911 -0.108721
# 성별  0.057039  0.822990  0.764911  1.000000  0.066900
# 나이 -0.055526  0.206245 -0.108721  0.066900  1.000000

# %%
sns.pairplot(data=df, hue='성별', hue_order=[1,0])
plt.show()
